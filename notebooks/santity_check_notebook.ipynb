# %%
import gymnasium as gym
import rware

# The environment name format is rware-{size}-{agents}ag-v2
ENV_STRING =  "rware-tiny-2ag-v2"
env = gym.make(ENV_STRING, render_mode="rgb_array")

obs, info = env.reset()

# %%
env.render()
# Out:
# /home/yahia/code_projects/multiagent-rware/.venv/lib/python3.14/site-packages/gymnasium/utils/passive_env_checker.py:269: UserWarning: WARN: RGB-array rendering should return a numpy array, got <class 'bool'>
#   logger.warn(
# True

# %%
env.close()
